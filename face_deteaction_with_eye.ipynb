# %%
import cv2
import matplotlib.pyplot as plt

# %%
#face_classifier=cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('haarcascade_eye.xml')
print(eye_classifier)
# Out:
# <CascadeClassifier 0x7fbb5497db10>

# %%
img=cv2.imread('ais.jpeg')
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()
# where 1.3 is the scaling factor, 
# and 5 is the number of nearest neighbors. 
# We can adjust these factors as per our convenience/results to improve our detector.
faces = face_classifier.detectMultiScale(img,1.3,5)
if faces is ():
    print("No face")

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,155),2)
    cv2.imshow('img',img)
    cv2.waitKey(0)
    plt.imshow(img)
    plt.show()
    roi_gray = gray[y:y+h, x:x+w]
    roi_color=  img[y:y+h, x:x+w]
    eyes=eye_classifier.detectMultiScale(roi_gray,1.3,5)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(10,65,76),2)
        cv2.imshow('img_eyes',img)
        cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(img)
plt.show()
